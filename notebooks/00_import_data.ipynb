# %%
# import_data.ipynb
# ------------------------------------------------------------------
# Downloads:
#   • data/raw/nbaallelo.csv                  (FiveThirtyEight)
#   • data/raw/wyattowalsh-basketball/*       (Kaggle, zipped → unzipped)
# ------------------------------------------------------------------

# --------------------------- 0. Imports ---------------------------
import os, sys, subprocess
from pathlib import Path
from shutil import which

# %%
# --------------------------- 0. Imports ---------------------------
import os, sys, subprocess
from pathlib import Path
from shutil import which

# %%
# -------------------- 0-bis.  Build key paths ---------------------
# • Where is this file running from?
NB_DIR = (
    Path(__file__).parent          # works if executed as a .py script
    if "__file__" in globals()     # __file__ absent inside classic Jupyter
    else Path.cwd()                # fall back to current working dir
)

# %%
# • Project root = folder that contains *data/*  and *notebooks/*.
PROJECT_ROOT = NB_DIR.parent if NB_DIR.name == "notebooks" else NB_DIR

# • Final download target →  data/raw/
DATA_DIR = PROJECT_ROOT / "data" / "raw"
DATA_DIR.mkdir(parents=True, exist_ok=True)
print(f"✓ Directory ready → {DATA_DIR.resolve()}")
# Out:
# ✓ Directory ready → /Users/brendanlam/Documents/GitHub/summer-2025-elo-for-nba/data/raw

# %%
# --------------- 1. Download FiveThirtyEight Elo CSV --------------
import requests

elo_url  = "https://raw.githubusercontent.com/fivethirtyeight/data/master/nba-elo/nbaallelo.csv"
elo_path = DATA_DIR / "nbaallelo.csv"

if not elo_path.exists():
    print("• Downloading FiveThirtyEight Elo data …")
    resp = requests.get(elo_url, timeout=30)
    resp.raise_for_status()
    elo_path.write_bytes(resp.content)
    print(f"✓ Saved → {elo_path}")
else:
    print(f"• Elo file already present → {elo_path}")
# Out:
# • Downloading FiveThirtyEight Elo data …
# ✓ Saved → /Users/brendanlam/Documents/GitHub/summer-2025-elo-for-nba/data/raw/nbaallelo.csv

# %%
os.environ['KAGGLE_USERNAME'] = 'brendanlammer'
os.environ['KAGGLE_KEY'] = '664b9998ecb645c43896e7ac81e93e82'

# %%
# --------------- 2. Download & unzip Kaggle dataset ---------------
dataset_id = "wyattowalsh/basketball"
print(f"• Downloading Kaggle dataset '{dataset_id}' …")

kaggle_exe = which("kaggle")          # locate kaggle CLI

if kaggle_exe is None:
    print("\n🚨 Kaggle CLI not found on PATH.\n"
          "    • Activate the Conda env built from environment.yml, OR\n"
          "    • Install kaggle in the current environment:\n"
          "        pip install kaggle==1.7.4.5\n")
else:
    cmd = [
        kaggle_exe, "datasets", "download",
        dataset_id, "-p", str(DATA_DIR), "--unzip", "--force"
    ]
    try:
        subprocess.run(cmd, check=True)
        print(f"✓ Kaggle dataset extracted → {DATA_DIR}")
    except subprocess.CalledProcessError as e:
        print("\n⚠️  Kaggle CLI failed.")
        print("    • Ensure ~/.kaggle/kaggle.json exists and is valid")
        print("    • Accept the dataset’s rules on kaggle.com")
        print(f"    Kaggle error: {e}")
# Out:
# • Downloading Kaggle dataset 'wyattowalsh/basketball' …
# Dataset URL: https://www.kaggle.com/datasets/wyattowalsh/basketball
# License(s): CC-BY-SA-4.0
# Downloading basketball.zip to /Users/brendanlam/Documents/GitHub/summer-2025-elo-for-nba/data/raw
# 100%|██████████| 697M/697M [00:00<00:00, 1.43GB/s]
# ✓ Kaggle dataset extracted → /Users/brendanlam/Documents/GitHub/summer-2025-elo-for-nba/data/raw

# %% [markdown]
# # Brendan/Kwame's original code

# %%
# import_data.ipynb  ▸  Cell 1
# -------------------------------------------------------------
# Downloads:
#   • data/nbaallelo.csv               (FiveThirtyEight)
#   • data/wyattowalsh-basketball/*    (Kaggle, zipped → unzipped)
# -------------------------------------------------------------
import os
import sys
import subprocess
from shutil import which
from pathlib import Path

# ------------------------------------------------------------------ #
# 1. Make ./data directory
# ------------------------------------------------------------------ #
DATA_DIR = Path("data")
DATA_DIR.mkdir(exist_ok=True)
print(f"✓ Directory ready → {DATA_DIR.resolve()}")

# ------------------------------------------------------------------ #
# 2. Download FiveThirtyEight Elo CSV
# ------------------------------------------------------------------ #
import requests

elo_url  = "https://raw.githubusercontent.com/fivethirtyeight/data/master/nba-elo/nbaallelo.csv"
elo_path = DATA_DIR / "nbaallelo.csv"

if not elo_path.exists():
    print("• Downloading FiveThirtyEight Elo data …")
    resp = requests.get(elo_url, timeout=30)
    resp.raise_for_status()
    elo_path.write_bytes(resp.content)
    print(f"✓ Saved → {elo_path}")
else:
    print(f"• Elo file already present → {elo_path}")

# ------------------------------------------------------------------ #
# 3. Download Kaggle dataset using the CLI script
# ------------------------------------------------------------------ #
dataset_id = "wyattowalsh/basketball"
print(f"• Downloading Kaggle dataset '{dataset_id}' …")

kaggle_exe = which("kaggle")  # finds kaggle(.exe) on PATH

if kaggle_exe is None:
    print("\n🚨 Kaggle CLI not found on PATH.\n"
          "    • Activate the Conda env built from environment.yml, OR\n"
          "    • Install kaggle in the current environment:\n"
          "        pip install kaggle==1.7.4.5\n")
else:
    cmd = [
        kaggle_exe, "datasets", "download",
        dataset_id, "-p", str(DATA_DIR), "--unzip", "--force"
    ]
    try:
        subprocess.run(cmd, check=True)
        print(f"✓ Kaggle dataset extracted → {DATA_DIR}")
    except subprocess.CalledProcessError as e:
        print("\n⚠️  Kaggle CLI failed.")
        print("    • Ensure ~/.kaggle/kaggle.json exists and is valid")
        print("    • Accept the dataset’s rules on kaggle.com")
        print(f"    Kaggle error: {e}")
# Out:
# ✓ Directory ready → /Users/brendanlam/Documents/GitHub/summer-2025-elo-for-nba/data
# • Elo file already present → data/nbaallelo.csv
# • Downloading Kaggle dataset 'wyattowalsh/basketball' …
# Dataset URL: https://www.kaggle.com/datasets/wyattowalsh/basketball
# License(s): CC-BY-SA-4.0
# Downloading basketball.zip to data
# 100%|██████████| 697M/697M [00:00<00:00, 1.40GB/s]
# ✓ Kaggle dataset extracted → data
